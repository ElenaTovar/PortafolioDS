# %% [markdown]
# # Practicas de Computer vision

# %%
# Establecemos nuestras credenciales
key='48d831b8be9b45c5b832a4d8546eeb28'
endpoint='https://dr-cv-lab1.cognitiveservices.azure.com/'

# %%
pip install azure-cognitiveservices-vision-computervision
# Out:
# Requirement already satisfied: azure-cognitiveservices-vision-computervision in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (0.9.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: azure-common~=1.1 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-computervision) (1.1.28)
# Requirement already satisfied: msrest>=0.5.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-computervision) (0.7.0)
# Requirement already satisfied: azure-core>=1.24.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.24.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (0.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2022.5.18.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.3.1)
# Requirement already satisfied: requests~=2.16 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.28.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (4.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\Luzel\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# conectamos con azure

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint,CognitiveServicesCredentials(key))

# %%
import vision
import os


#obtenemos la imagen
image_path='./data/vision/image01.jpg'
image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description)
vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['person', 'building', 'outdoor', 'city'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x00000248BF5A9030>], 'request_id': '3924a8b2-7dc3-4318-93e9-3a8c692d7450', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x00000248BF2A7550>, 'model_version': '2021-05-01'}

# %%
image_path = './data/vision/image02.jpg'
image_stream = open(image_path, "rb")
description=client.describe_image_in_stream(image_stream)
print(description)
vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['person', 'indoor', 'wall', 'posing', 'people', 'standing'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x00000248BF593730>], 'request_id': '9874c5d2-4386-4077-958b-f6285f72b427', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x00000248BF592800>, 'model_version': '2021-05-01'}

# %%
image_path='./data/vision/image01.jpg'
features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']
image_stream = open(image_path, "rb")
analysis= client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# ## Face API
# !pip install azure-cognitiveservices-vision-face

# %%
# !pip install azure-cognitiveservices-vision-face
# Out:
# Requirement already satisfied: azure-cognitiveservices-vision-face in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (0.6.0)
# Requirement already satisfied: azure-common~=1.1 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-face) (1.1.28)
# Requirement already satisfied: msrest>=0.5.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-face) (0.7.0)
# Requirement already satisfied: azure-core>=1.24.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.24.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (0.6.1)
# Requirement already satisfied: requests~=2.16 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2.28.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2022.5.18.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (4.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-face) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-face) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\luzel\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Luzel\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
key = 'fb7c70602c384f5cbc261b4d6911803a'
endpoint = 'https://face-dt-lab2.cognitiveservices.azure.com/'

# %%
# conectamos con azure

from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint,CognitiveServicesCredentials(key))

# %%
import faces
import os

# %%
image_path = './data/vision/image02.jpg'
image_stream = open(image_path, "rb")
detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces)

# %%
image_path = './data/vision/image02.jpg'
image_stream = open(image_path, "rb")
detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
image_path = './data/vision/image02.jpg'
image_stream = open(image_path, "rb")
attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image=image_stream, return_face_attributes=attributes)
faces.show_face_attributes(image_path,detected_faces)

# %%
image_path = './data/vision/image01.jpg'
image_stream = open(image_path, "rb")
attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image=image_stream, return_face_attributes=attributes)
faces.show_face_attributes(image_path,detected_faces)
